# %% [markdown]
# # Transformation Interpolations:  SDSS DR13 <--> GAIA EDR3
#
# _Douglas L. Tucker_
#
# _2022.07.2_

# %% [markdown]
# ## Initial Setup

# %%
import numpy as np
import pandas as pd

import os
import sys
import glob
import math
import datetime

from collections import OrderedDict as odict

from astropy.io import fits
from astropy.table import Table

import fitsio

from scipy import interpolate
from scipy.optimize import leastsq

import healpy as hp
import healpixTools

import extinction

import paramFile

import plotly
from plotly.offline import download_plotlyjs, plot, iplot
import plotly.graph_objs as go

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Input Parameters

# %%
# GAIA-->SDSS (toSDSS=True) or SDSS-->GAIA (toSDSS=False)...
#toSDSS = True
toSDSS = False


if toSDSS:
    # List of SDSS bands on which to run the transform fit...
    bandList = ['g_sdss', 'r_sdss', 'i_sdss', 'z_sdss', 'Y_sdss']
    # If GAIA-->SDSS, then the mag and color to fit against are GAIA...
    # Dictionary of corresponding bands from the other survey...
    matchBand_dict = {'g_sdss':'G_gaia', 'r_sdss':'G_gaia', 'i_sdss':'G_gaia', 'z_sdss':'G_gaia', 'Y_sdss':'G_gaia'}
    # Color to fit against...
    color_name_1_dict = {'g_sdss':'BP_RP_gaia', 'r_sdss':'BP_RP_gaia', 'i_sdss':'BP_RP_gaia', 'z_sdss':'BP_RP_gaia', 'Y_sdss':'BP_RP_gaia'}
    # Name of color_name_1 as the label in the QA plots...
    colorLabel_1_dict = {'g_sdss':'$(BP-RP)$', 'r_sdss':'$(BP-RP)$', 'i_sdss':'$(BP-RP)$', 'z_sdss':'$(BP-RP)$', 'Y_sdss':'$(BP-RP)$'}

else:    
    # List of GAIA bands on which to run the transform fit...
    bandList = ['G_gaia']
    # If SDSS-->GAIA, then the mag and color to fit against are SDSS...
    # Dictionary of corresponding bands from the other survey...
    matchBand_dict = {'G_gaia':'i_sdss'}
    # Color to fit against...
    color_name_1_dict = {'G_gaia':'gi_sdss'}
    # Name of color_name_1 as the label in the QA plots...
    colorLabel_1_dict = {'G_gaia':'$(g-i)_{sdss}$'}


# Size of the binsize in color
color_binsize = 0.10

# Identify directory containing the SDSS/Stetson match file...
matchDir = './'

# Name of the DES/SDSS/GaiaEDR3 match file in matchDir
matchFile = 'match_y6a2_stripe82area_stars_GAIAedr3_SDSSDR13.fits'


# Base name of fit results output file...
if toSDSS:
    resultsFileBaseName = 'transInterp.gaia_to_sdss'
else:
    resultsFileBaseName = 'transInterp.sdss_to_gaia'

# Base name of QA plot output files...
if toSDSS:
    qaFileBaseName = 'qaPlot.gaia_to_sdss.interp'
else:
    qaFileBaseName = 'qaPlot.sdss_to_gaia.interp'

# Verbosity level (0, 1, 2, 3, ...)
verbose = 2

# %% [markdown]
# ## Define Some Modules

# %%
# From Zeljko Ivezic:
# Robust estimate of standard deviation: 0.741*(q75-q25)
#  sigmaG = 0.741*(np.percentile(yAux,75)-np.percentile(yAux,25))
# Uncertainty of the median: sqrt(pi/2)*st.dev/sqrt(N)
#  sigGbin[i] = np.sqrt(np.pi/2)*sigmaG/np.sqrt(nPts[i])

def robustStdDev(data):
    sd = 0.741*(np.percentile(data,75)-np.percentile(data,25))
    return sd

def uncMedian(data, npts):
    sd = robustStdDev(data)
    uncMedian = np.sqrt(np.pi/2)*sd/np.sqrt(npts)
    return uncMedian

# %%
##################################

def interp1ColorQAPlots1(df, df1, color_name_1, color1_min, color1_max, 
                         title, dmagLabel, outputFileName, verbose):

        
    # Create linear interpolation of the median dmag vs. color bin calculated above...
    response = interpolate.interp1d(df1.index.values.astype(float), df1.bin_median.values, \
                                bounds_error=False, fill_value=0., kind='linear')    

    # Calculate and apply the offset for the individual stars in df, 
    #  based on the linear interpolation calculated above...
    df['offset'] = response(df[color_name_1].values)    
    df['res'] = df['dmag'] - df['offset']    
    if verbose>1:
        print 
        print df[[color_name_1, 'offset', 'res']].head()
        print 

    # Calculate the 'robust' RMS of the residuals....
    rms = robustStdDev(df['res'].values)


    # Identify range to plot in the dmag (Y-axis) direction...
    dmag_desc = df['dmag'].describe(percentiles=[0.001, 0.999])
    if verbose>1:
        print dmag_desc
    dmag_min = math.floor(10*dmag_desc['0.1%'])/10.
    dmag_max = math.ceil(10*dmag_desc['99.9%'])/10.

    dmag_mask = (df['dmag'] >= dmag_min) & (df['dmag'] <= dmag_max)
    df_dmag_mask = df[dmag_mask]
    

    # Identify range to plot in the residuals (Y-axis) direction...
    res_desc = df['res'].describe(percentiles=[0.01, 0.99])
    if verbose>1:
        print 
        print res_desc
        print 
    #res_min = math.floor(10*dmag_desc['1%'])/10.
    #res_max = math.ceil(10*dmag_desc['99%'])/10.
    # What the heck; let's just set this to -0.10 mag --> +0.10 mag...
    res_min = -0.10
    res_max = +0.10


    # For 2d binning below, we mask df for just those stars within 
    #  the res_min, res_max range...
    res_mask = (df['res'] >= res_min) & (df['res'] <= res_max)
    df_res_mask = df[res_mask]
    
    
    # Prepare QA plots...
    #fig = plt.figure(figsize=(40,20))
    fig = plt.figure(figsize=(20,10))
    fig.subplots_adjust(hspace=0.3)
    
    # Modify matplotlib font...
    #font = {'family' : 'normal',
    #        'weight' : 'bold',
    #       'size'   : 22}
    #matplotlib.rc('font', **font)    
    plt.rcParams.update({'font.size': 24})

    
    ## Include a supertitle to the matplotlob figure...
    #fig.suptitle('This is the superTitle')

    
    # Plot 1:  Descriptive text...
    plt.subplot(221)
    plot1Text = """%s \n\n\n\n%s vs. %s\n\n[rms: %.3f] \n\n[%.1f < %s < %.1f]""" % \
                    (title, dmagLabel, colorLabel_1, rms, color1_min, colorLabel_1, color1_max)
    plt.text(0.1,0.00,plot1Text)
    plt.axis('off')

    
    # Plot 2:  2D hexbin histogram of dmag vs. color1...
    plt.subplot(222)
    hb=plt.hexbin(df_dmag_mask[color_name_1].values, df_dmag_mask['dmag'].values, \
                      gridsize=100, bins='log', cmap='inferno')
    ax=plt.axis([color1_min, color1_max, dmag_min, dmag_max])
    plt.xlabel(colorLabel_1)
    plt.ylabel(dmagLabel)
    cb = fig.colorbar(hb)
    #cb.set_label('Number')
    cb.set_label('log10(N)')
    plt.grid(color='white')
    plt.grid(True)
    # Overplot the binned values calculated above:
    plt.errorbar(df1.index.values.astype(float), df1.bin_median.values, yerr=df1.bin_unc.values, fmt='o')

    
    # Plot 3:  1d histogram of residuals...
    plt.subplot(223) 
    plt.hist(df_res_mask.loc[:,'res'],bins=100)
    plt.xlabel('residuals [mag]')
    plt.ylabel('Number')
    plt.xlim([res_min, res_max])
    plt.grid(True)
    plt.grid(color='black')

    
    # Plot 4:  2d hexbin histogram of residuals vs. color1...
    plt.subplot(224) 
    hb=plt.hexbin(df_res_mask.loc[:, color_name_1].values, df_res_mask.loc[:,'res'].values, \
                  gridsize=100, bins='log', cmap='inferno')
    ax=plt.axis([color1_min, color1_max, res_min, res_max])
    plt.xlabel(colorLabel_1)
    plt.ylabel('Residuals')
    cb = fig.colorbar(hb)
    #cb.set_label('Number')
    cb.set_label('log10(N)')
    plt.grid(color='white')
    plt.grid(True)
    
    
    # Plot...
    plt.tight_layout()
    

    # Save QA plots to file...
    plt.savefig(outputFileName)    
    

    return 0


##################################

# %% [markdown]
# ## Read in Matched Catalog

# %%
matchFile = os.path.join(matchDir,matchFile)
print matchFile
# Out:
# ./match_y6a2_stripe82area_stars_GAIAedr3_SDSSDR13.fits

# %%
# Check to make sure matchFile exists...
if os.path.isfile(matchFile)==False:
    print """ERROR:  matchFile %s does not exist...""" % (matchFile)
if verbose > 0:
    print 'matchFile: ', matchFile
# Out:
# matchFile:  ./match_y6a2_stripe82area_stars_GAIAedr3_SDSSDR13.fits

# %%
tab = Table.read(matchFile, format='fits')
tab
# Out:
# WARNING: UnitsWarning: 'e-/s' did not parse as fits unit: At col 0, Unit 'e' not supported by the FITS standard.  [astropy.units.core]
# WARNING: UnitsWarning: '[cgs]' did not parse as fits unit: Invalid character at col 0 [astropy.units.core]
# <Table masked=True length=581320>
# COADD_OBJECT_ID_1     RA        DEC    ...  run  stripe      Separation
#                                        ...                     arcsec
#       int64        float64    float64  ... int16 int32        float64
# ----------------- ---------- --------- ... ----- ------ --------------------
#        1033597189    5.8e-05 -2.417387 ...  6361   1188  0.07230640210855878
#        1032384224   0.000101 -2.967177 ...  7778     83   0.1316573062091628
#        1032145903    0.00011  3.352002 ...  7717     81  0.08141182963157605
#        1034106643   0.000249 -0.838739 ...  4263     82  0.14702483672352457
#        1034253701   0.000297 -1.034322 ...  2662     82  0.15357289285031975
#        1034175401   0.000446 -4.093737 ...  6372   1188  0.16786431958104808
#        1033051513   0.000603  2.368938 ...  7712     81  0.10182586829113315
#        1032398196   0.000712 -3.137557 ...  7907     83  0.16672135962971998
#        1031850607   0.000722 -1.804559 ...  7778     83   0.2546506001166444
#               ...        ...       ... ...   ...    ...                  ...
#        1034107778  359.97836 -0.854059 ...  2662     82  0.08840337081992884
#        1034088565 359.978779 -0.642211 ...  4263     82  0.16023338834738446
#        1031853110 359.978961 -1.830692 ...  7778     83   0.1192791345025918
# 10      7881.0    84.0    0.037900
# 11      7727.0    80.0    0.073349
# 12      7778.0    83.0    0.057173
# 13      7907.0    83.0    0.071240
# 14      7712.0    81.0    0.086163
# 15      4145.0    82.0    0.041003
# 16      4263.0    82.0    0.084950
# 17      7907.0    83.0    0.101586
# 18      7727.0    80.0    0.015635
# 19      2662.0    82.0    0.185841
# 20      7727.0    80.0    0.071988
# 21      4263.0    82.0    0.480044
# 22      7727.0    80.0    0.039257
# 23      2728.0    82.0    0.053563
# 24      6361.0  1188.0    0.215512
# 25      6372.0  1188.0    0.194567
# 26      7712.0    81.0    0.088689
# 27      7717.0    81.0    0.105856
# 28      6361.0  1188.0    0.053195
# 29      6361.0  1188.0    0.050564
# ...        ...     ...         ...
# 581290  7727.0    80.0    0.136412
# 581291  6372.0  1188.0    0.077446
# 581292  7717.0    81.0    0.050010
# 581293  2728.0    82.0    0.213640
# 581294  2728.0    82.0    0.105058
# 581295  7907.0    83.0    0.139257
# 581296  6372.0  1188.0    0.171540
# 581297  7907.0    83.0    0.059574
# 581298  7907.0    83.0    0.026420
# 581299  7907.0    83.0    0.019944
# 581300  7754.0    80.0    0.050703
# 581301  7712.0    81.0    0.082675
# 581302  6361.0  1188.0    0.061202
# 581303  7717.0    81.0    0.058370
# 581304  7778.0    83.0    0.076639
# 581305  4145.0    82.0    0.042017
# 581306  7778.0    83.0    0.286839
# 581307  6361.0  1188.0    0.899674
# 581308  7778.0    83.0    0.040907
# 581309  7712.0    81.0    0.062157
# 581310  2662.0    82.0    0.088403
# 581311  4263.0    82.0    0.160233
# 581312  7778.0    83.0    0.119279
# 581313  7712.0    81.0    0.049201
# 581314  7778.0    83.0    0.032814
# 581315  6361.0  1188.0    0.270782
# 581316  4874.0    82.0    0.082731
# 581317  4263.0    82.0    0.086029
# 581318  7712.0    81.0    0.072259
# 581319  2728.0    82.0    0.238595
#
# [581320 rows x 448 columns]

# %%
df.columns
# Out:
# Index([u'COADD_OBJECT_ID_1', u'RA', u'DEC', u'ALPHAWIN_J2000_1',
#        u'DELTAWIN_J2000_1', u'PFW_ATTEMPT_ID_1', u'OBJECT_NUMBER_1',
#        u'PARENT_NUMBER_1', u'TILENAME_1', u'L_1',
#        ...
#        u'psfMag_i', u'psfMag_z', u'psfMagErr_u', u'psfMagErr_g',
#        u'psfMagErr_r', u'psfMagErr_i', u'psfMagErr_z', u'run', u'stripe',
#        u'Separation'],
#       dtype='object', length=448)

# %%
# Rename columns...
df.rename(columns={'ra_2':'RA_sdss',
                   'dec_2':'DEC_sdss',
                   'psfMag_u':'u_sdss',
                   'psfMag_g':'g_sdss',
                   'psfMag_r':'r_sdss',
                   'psfMag_i':'i_sdss',
                   'psfMag_z':'z_sdss',
                   'psfMagErr_u':'u_err_sdss',
                   'psfMagErr_g':'g_err_sdss',
                   'psfMagErr_r':'r_err_sdss',
                   'psfMagErr_i':'i_err_sdss',
                   'psfMagErr_z':'z_err_sdss',                   
                   'phot_g_mean_mag_corrected':'G_gaia',
                   'phot_g_mean_mag_error_corrected':'G_err_gaia',
                   'bp_rp':'BP_RP_gaia',
                   'phot_bp_mean_mag_error':'BP_err_gaia',
                   'phot_rp_mean_mag_error':'RP_err_gaia'
                  },inplace=True)

df.head(5)
# Out:
#    COADD_OBJECT_ID_1        RA       DEC  ALPHAWIN_J2000_1  DELTAWIN_J2000_1  \
# 0       1.033597e+09  0.000058 -2.417387          0.000058         -2.417387
# 1       1.032384e+09  0.000101 -2.967177          0.000101         -2.967177
# 2       1.032146e+09  0.000110  3.352002          0.000110          3.352002
# 3       1.034107e+09  0.000249 -0.838739          0.000249         -0.838739
# 4       1.034254e+09  0.000297 -1.034322          0.000297         -1.034322
#
#    PFW_ATTEMPT_ID_1  OBJECT_NUMBER_1  PARENT_NUMBER_1    TILENAME_1  \
# 0         2758897.0           7033.0           7252.0  DES0000-0207
# 1         2764753.0          20554.0          22091.0  DES0000-0250
# 2         2763748.0          10494.0          11267.0  DES0000+0335
# 3         2764748.0          20138.0          22019.0  DES2359-0041
# 4         2764748.0           3080.0           2902.0  DES2359-0041
#
#          L_1     ...         i_sdss     z_sdss  u_err_sdss  g_err_sdss  \
# 0  94.259300     ...      18.352320  18.197308    0.105668    0.017967
# 1  93.743797     ...      17.273417  16.676876    0.189597    0.026167
# 2  98.794853     ...      16.957182  16.818913    0.028147    0.018261
# 3  95.649406     ...      18.321367  18.298330    0.039136    0.023591
# 4  95.484200     ...      16.302778  16.103003    0.041825    0.020095
#
#    r_err_sdss  i_err_sdss  z_err_sdss     run  stripe  Separation
# 0    0.016583    0.023540    0.027509  6361.0  1188.0    0.072306
# 1    0.015462    0.021712    0.017184  7778.0    83.0    0.131657
# 2    0.025981    0.018688    0.016255  7717.0    81.0    0.081412
# 3    0.014854    0.019058    0.027282  4263.0    82.0    0.147025
# 4    0.013199    0.018106    0.014031  2662.0    82.0    0.153573
#
# [5 rows x 448 columns]

# %% [markdown]
# ## Add Columns to Matched Catalog Data Frame

# %%
# Add color columns...
df.loc[:,'ug_sdss'] = df.loc[:,'u_sdss'] - df.loc[:,'g_sdss']
df.loc[:,'gr_sdss'] = df.loc[:,'g_sdss'] - df.loc[:,'r_sdss']
df.loc[:,'ri_sdss'] = df.loc[:,'r_sdss'] - df.loc[:,'i_sdss']
df.loc[:,'iz_sdss'] = df.loc[:,'i_sdss'] - df.loc[:,'z_sdss']
df.loc[:,'gi_sdss'] = df.loc[:,'g_sdss'] - df.loc[:,'i_sdss']

# %%
# Insert dmag column...
df.loc[:,'dmag'] = -9999.

# %% [markdown]
# ## Create Initial Mask

# %%
#mask = ( ( df[color_name_1] > -1. ) & ( df[color_name_1] < 4.0 ) )
#mask = ( ( df['BP_RP_gaia'] > -0.2 ) & ( df['BP_RP_gaia'] < 1.5 ) )
mask1 = df['BP_RP_gaia'] > -1.0
mask2 = df['BP_RP_gaia'] < 4.0
mask3 = df['G_gaia'] > 16.0
mask4 = df['G_gaia'] < 19.5
mask_gaia = mask1 & mask2 & mask3 & mask4

mask1 = df["u_sdss"] > 0.
mask2 = df["g_sdss"] > 0.
mask3 = df["r_sdss"] > 0.
mask4 = df["i_sdss"] > 0.
mask5 = df["z_sdss"] > 0.
mask6 = df["u_err_sdss"] <= 0.05
mask7 = df["g_err_sdss"] <= 0.02
mask8 = df["r_err_sdss"] <= 0.02
mask9 = df["i_err_sdss"] <= 0.02
mask10 = df["z_err_sdss"] <= 0.02
mask11 = df["gi_sdss"] > -0.5
mask12 = df["gi_sdss"] < 3.5

mask_sdss = mask1 & mask2 & mask3 & mask4 & mask5 & mask6 & mask7 & mask8 & mask9 & mask10 & mask11 & mask12

mask = mask_gaia & mask_sdss

# %% [markdown]
# ## Make Backup Copies of Initial Mask and Original Data Frame

# %%
#df = df_orig.copy()
#mask = mask_orig.copy()

# %%
# Make a backup copy of original df...
df_orig = df.copy()

# Make a backup copy of original mask...
mask_orig = mask.copy()

# %%
# Sanity check...
band = bandList[0]
magName = band
magName_match = matchBand_dict[band]
color_name_1 = color_name_1_dict[band]
colorLabel_1 = colorLabel_1_dict[band]
print band
print magName_match
print color_name_1
print colorLabel_1
# Out:
# G_gaia
# i_sdss
# gi_sdss
# $(g-i)_{sdss}$

# %%
band in bandList[0]
magName = band
magName_match = matchBand_dict[band]
color_name_1 = color_name_1_dict[band]
colorLabel_1 = colorLabel_1_dict[band]

df.loc[:,'dmag'] = df.loc[:,magName] - df.loc[:,magName_match]
df.plot(color_name_1,'dmag', kind='scatter', grid=True, s=1.0)

# %%
fig = plt.figure(figsize=(20,10))
hb=plt.hexbin(df.loc[:, color_name_1].values, df.loc[:,'dmag'].values, \
                  gridsize=300, bins='log', cmap='inferno')
#hb=plt.hexbin(df.loc[:, color_name_1].values, df.loc[:,'dmag'].values, \
#                  gridsize=300, cmap='inferno')
ax=plt.axis([-0.5, 2.0, -0.5, 1.0])
plt.xlabel(colorLabel_1)
plt.ylabel('dmag')
cb = fig.colorbar(hb)
#cb.set_label('Number')
cb.set_label('log10(N)')
plt.grid(color='white')
plt.grid(True)

# %% [markdown]
# ## Run Fit in Each Filter Band

# %%
for band in bandList:
    
    print 
    print 
    print 
    print "# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # "
    print band
    print "# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # "
    print 
    
    magName = band
    magName_match = matchBand_dict[band]
    color_name_1 = color_name_1_dict[band]
    colorLabel_1 = colorLabel_1_dict[band]

    
    # Grab the original version of df from the backup copy...
    df = df_orig.copy()

    # Grab the original version of mask from the backup copy...
    mask = mask_orig.copy()

    # Update dmag column...
    df.loc[:,'dmag'] = df.loc[:,magName] - df.loc[:,magName_match]

    # Update mask...
    mask1 = abs(df['dmag']) <= 10.
    mask2 = ( ( df[color_name_1] > -3. ) & ( df[color_name_1] < 6.0 ) )
    mask = mask & mask1 & mask2

    # make a copy of original df, overwriting the old one...
    df = df[mask].copy()

    # Identify dmag and color1 series...
    dmag =  df.loc[:,'dmag']
    color1 = df.loc[:,color_name_1]


    # Calculate the color range to bin and the number of bins, 
    #  based on the 0.01%-99.99% color range...
    color1_desc = df[color_name_1].describe(percentiles=[0.0001, 0.9999])
    color1_min = math.floor(10*color1_desc['0.01%'])/10.
    color1_max = math.ceil(10*color1_desc['99.99%'])/10.
    if verbose>1:
        print 
        print color1_desc
        print color1_min, color1_max 
        print 
    binsize = color_binsize
    ranges = np.arange(color1_min,color1_max+binsize,binsize)
    # Label the bins by their mid-point...
    labels = np.arange(color1_min,color1_max,binsize) + 0.5*binsize
    
    #nbins = int((color1_max-color1_min)/binsize)+1
    #ranges = np.linspace(color1_min, color1_max, nbins+1)
    ## Label the bins by their mid-point...
    #labels = np.linspace(color1_min, color1_max-binsize, nbins) + 0.5*binsize

    #nbins = math.floor((color1_max-color1_min)/binsize) + 1
    #ranges = np.linspace(color1_min, color1_max, nbins)
    ## Label the bins by their mid-point...
    #labels = np.linspace(color1_min, color1_max-binsize, nbins-1) + 0.5*binsize
    
    if verbose:
        print ranges
        print labels
    
    # Bin the data, adding "bin_interval" and "bin_label' to the df dataframe...
    df['bin_interval'] = pd.cut(df[color_name_1], bins=ranges, precision=0)
    df['bin_label'] = pd.cut(df[color_name_1], bins=ranges, labels=labels)
    if verbose>1:
        print 
        print df[[color_name_1,'bin_interval','bin_label']].head()
        print 

    # Perform pandas grouping/aggregating functions on sigma-clipped Data Frame...
    df_grp = df.groupby(['bin_label'])
    bin_interval = df_grp['bin_interval'].first()
    dmag_num = df_grp['dmag'].count()
    dmag_mean = df_grp['dmag'].mean()
    dmag_sd = df_grp['dmag'].std()
    dmag_err = dmag_sd/np.sqrt(dmag_num-1)
    dmag_median = df_grp['dmag'].median()
    dmag_rsd = df_grp['dmag'].apply(robustStdDev)
    dmag_unc = np.sqrt(np.pi/2)*dmag_rsd/np.sqrt(dmag_num)

    # Rename some of the pandas series...
    dmag_num.name    = 'bin_num'
    dmag_mean.name   = 'bin_mean'
    dmag_sd.name     = 'bin_stddev'
    dmag_err.name    = 'bin_stderr'
    dmag_median.name = 'bin_median'
    dmag_rsd.name    = 'bin_rstddev'
    dmag_unc.name    = 'bin_unc'
    
    # Create new data frame containing all the relevant aggregate quantities...
    df1 = pd.concat( [bin_interval, dmag_num, \
                      dmag_mean, dmag_sd, dmag_err, \
                      dmag_median, dmag_rsd, dmag_unc, ], \
                    join='outer', axis=1 )
    
    if verbose>1:
        print 
        print df1
        print 
    
    
    # Create results output file...
    resultsFile = """%s.%s_%s.csv""" % (resultsFileBaseName, band, color_name_1)
    df1.to_csv(resultsFile)
    if verbose>1:
        print """Writing binned values to %s""" % (resultsFile)

    
    # Create name for QA plot output file...
    outputFileName = """qaPlot_%s.%s_%s.png""" % (resultsFileBaseName, band, color_name_1)

    # Create title and labels for use in QA plots...
    title = """%s --> %s""" % (magName_match, magName)
    dmagLabel = """%s - %s""" % (magName, magName_match)


    # Create QA plots...
    status = interp1ColorQAPlots1(df, df1, color_name_1, color1_min, color1_max, 
                                     title, dmagLabel, outputFileName, verbose)
# Out:
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# G_gaia
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
#
#
# count     50721.000000
# mean          0.808503
# std           0.255265
# min          -0.495221
# 0.01%        -0.367543
# 50%           0.764324
# 99.99%        2.088335
# max           2.375071
# Name: gi_sdss, dtype: float64
# -0.4 2.1
#
# [-4.00000000e-01 -3.00000000e-01 -2.00000000e-01 -1.00000000e-01
#  -1.11022302e-16  1.00000000e-01  2.00000000e-01  3.00000000e-01
#   4.00000000e-01  5.00000000e-01  6.00000000e-01  7.00000000e-01
#   8.00000000e-01  9.00000000e-01  1.00000000e+00  1.10000000e+00
#   1.20000000e+00  1.30000000e+00  1.40000000e+00  1.50000000e+00
#   1.60000000e+00  1.70000000e+00  1.80000000e+00  1.90000000e+00
#   2.00000000e+00  2.10000000e+00]
# [-0.35 -0.25 -0.15 -0.05  0.05  0.15  0.25  0.35  0.45  0.55  0.65  0.75
#   0.85  0.95  1.05  1.15  1.25  1.35  1.45  1.55  1.65  1.75  1.85  1.95
#   2.05]
#
#      gi_sdss bin_interval bin_label
# 12  0.482489   (0.4, 0.5]      0.45
# 19  0.429234   (0.4, 0.5]      0.45
# 23  0.774691   (0.7, 0.8]      0.75
# 40  0.538134   (0.5, 0.6]      0.55
# 50  0.648558   (0.6, 0.7]      0.65
#
#
#            bin_interval  bin_num  bin_mean  bin_stddev  bin_stderr  \
# bin_label
# -0.35      (-0.4, -0.3]       20 -0.270548    0.017719    0.004065
# -0.25      (-0.3, -0.2]       33 -0.197273    0.168760    0.029833
# -0.15      (-0.2, -0.1]       37 -0.086104    0.197214    0.032869
# -0.05        (-0.1, -1]       53 -0.063498    0.158653    0.022001
#  0.05         (-1, 0.1]       47  0.017057    0.141944    0.020928
#  0.15        (0.1, 0.2]       46  0.025887    0.110065    0.016407
#  0.25        (0.2, 0.3]      121  0.049368    0.099022    0.009039
#  0.35        (0.3, 0.4]      571  0.075263    0.038468    0.001611
#  0.45        (0.4, 0.5]     2162  0.118034    0.029539    0.000635
#  0.55        (0.5, 0.6]     6607  0.157590    0.027048    0.000333
#  0.65        (0.6, 0.7]     9975  0.191964    0.028634    0.000287
#  0.75        (0.7, 0.8]     8534  0.228006    0.033969    0.000368
#  0.85        (0.8, 0.9]     6831  0.261396    0.033802    0.000409
#  0.95          (0.9, 1]     5400  0.292356    0.032895    0.000448
#  1.05          (1, 1.1]     3688  0.321785    0.041101    0.000677
#  1.15        (1.1, 1.2]     2508  0.350715    0.043034    0.000859
#  1.25        (1.2, 1.3]     1645  0.377168    0.042757    0.001055
#  1.35        (1.3, 1.4]     1091  0.404299    0.056667    0.001716
#  1.45        (1.4, 1.5]      685  0.426717    0.047565    0.001819
#  1.55        (1.5, 1.6]      354  0.451730    0.039343    0.002094
#  1.65        (1.6, 1.7]      189  0.476087    0.041672    0.003039
#  1.75        (1.7, 1.8]       74  0.504222    0.048283    0.005651
#  1.85        (1.8, 1.9]       27  0.569282    0.123111    0.024144
#  1.95          (1.9, 2]       11  0.577497    0.074844    0.023668
#  2.05          (2, 2.1]        4  0.598935    0.031766    0.018340
#
#            bin_median  bin_rstddev   bin_unc
# bin_label
# -0.35       -0.268417     0.010959  0.003071
# -0.25       -0.221722     0.023383  0.005102
# -0.15       -0.165550     0.029549  0.006088
# -0.05       -0.112892     0.022992  0.003958
#  0.05       -0.053577     0.084591  0.015465
#  0.15       -0.010953     0.058676  0.010843
#  0.25        0.037973     0.025102  0.002860
#  0.35        0.078394     0.016542  0.000868
#  0.45        0.117900     0.017112  0.000461
#  0.55        0.156188     0.015646  0.000241
#  0.65        0.189880     0.015685  0.000197
#  0.75        0.224797     0.015539  0.000211
#  0.85        0.258308     0.015427  0.000234
#  0.95        0.288819     0.015474  0.000264
#  1.05        0.317340     0.015122  0.000312
#  1.15        0.344853     0.015169  0.000380
#  1.25        0.371418     0.015142  0.000468
#  1.35        0.397262     0.014949  0.000567
#  1.45        0.420824     0.015619  0.000748
#  1.55        0.444393     0.015010  0.001000
#  1.65        0.468567     0.014820  0.001351
#  1.75        0.493201     0.014191  0.002068
#  1.85        0.524051     0.024147  0.005824
#  1.95        0.557392     0.028123  0.010627
#  2.05        0.602365     0.029275  0.018346
#
# Writing binned values to transInterp.sdss_to_gaia.G_gaia_gi_sdss.csv
#
#      gi_sdss    offset       res
# 12  0.482489  0.130339 -0.004276
# 19  0.429234  0.109696 -0.016052
# 23  0.774691  0.233071 -0.000357
# 40  0.538134  0.151645  0.002797
# 50  0.648558  0.189394  0.370746
#
# count    50721.000000
# mean         0.242259
# std          0.089622
# min         -0.363127
# 0.1%        -0.210578
# 50%          0.231750
# 99.9%        0.752780
# max          1.696989
# Name: dmag, dtype: float64
#
# count    50721.000000
# mean         0.003365
# std          0.036189
# min         -0.512361
# 1%          -0.030233
# 50%         -0.000100
# 99%          0.126558
# max          1.310260
# Name: res, dtype: float64

# %%
# %ls -FlthrG
# Out:
# total 16G
# -rwxr-xr-x 1 dtucker   45K Jun 13  2018 sdss_des_transform.py*
# -rw-rw-r-- 1 dtucker 1023M Nov 17  2020 y6a2_stripe82area_stars_000001.fits
# -rw-rw-r-- 1 dtucker 1023M Nov 17  2020 y6a2_stripe82area_stars_000002.fits
# -rw-rw-r-- 1 dtucker  204M Nov 17  2020 y6a2_stripe82area_stars_000003.fits
# -rw-rw-r-- 1 dtucker   275 Nov 17  2020 y6a2_stripe82area_stars.sql
# -rw-rw-r-- 1 dtucker  2.2G Nov 17  2020 y6a2_stripe82area_stars.fits
# -rw-rw-r-- 1 dtucker  872M Nov 17  2020 match_y6a2_stripe82area_stars_SDSSDR13.fits
# -rw-rw-r-- 1 dtucker  2.0G Nov 17  2020 match_y6a2_stripe82area_stars_PS1DR2.fits
# -rw-rw-r-- 1 dtucker  2.5M Nov 18  2020 temp.csv
# -rw-rw-r-- 1 dtucker  620K Nov 19  2020 TransformationEquations_DES_DR2_SDSS_DR13_orig.ipynb
# -rw-rw-r-- 1 dtucker   83K Nov 20  2020 plot.uNUV.NUVg.qa1.png
# -rw-rw-r-- 1 dtucker   83K Nov 20  2020 qaPlot.ps1_to_des.dmag_g.$(g-i)_{ps1}$.qa1.png
# -rw-rw-r-- 1 dtucker   83K Nov 20  2020 qaPlot.ps1_to_des.dmag_g.gi_ps1.qa1.png
# -rw-rw-r-- 1 dtucker   82K Nov 20  2020 qaPlot.sdss_to_des.dmag_g.gi_sdss.norder1.qa1.png
# -rw-rw-r-- 1 dtucker
ri_des.norder1.qa1.png
# -rw-rw-r-- 1 dtucker   637 Mar  9  2021 transFit.sdss_to_des.dmag.ri_des.norder1.csv
# -rw-rw-r-- 1 dtucker  2.7K Mar 15  2021 transInterp.sdss_to_des.g_ri_des.csv
# -rw-rw-r-- 1 dtucker  349K Mar 15  2021 qaPlot_transInterp.sdss_to_des.g_ri_des.png
# -rw-rw-r-- 1 dtucker  2.8K Mar 15  2021 transInterp.sdss_to_des.r_ri_des.csv
# -rw-rw-r-- 1 dtucker  359K Mar 15  2021 qaPlot_transInterp.sdss_to_des.r_ri_des.png
# -rw-rw-r-- 1 dtucker  2.8K Mar 15  2021 transInterp.sdss_to_des.i_ri_des.csv
# -rw-rw-r-- 1 dtucker  343K Mar 15  2021 qaPlot_transInterp.sdss_to_des.i_ri_des.png
# -rw-rw-r-- 1 dtucker  2.8K Mar 15  2021 transInterp.sdss_to_des.z_ri_des.csv
# -rw-rw-r-- 1 dtucker  327K Mar 15  2021 qaPlot_transInterp.sdss_to_des.z_ri_des.png
# -rw-rw-r-- 1 dtucker  2.8K Mar 15  2021 transInterp.sdss_to_des.g_gr_des.csv
# -rw-rw-r-- 1 dtucker  373K Mar 15  2021 qaPlot_transInterp.sdss_to_des.g_gr_des.png
# -rw-rw-r-- 1 dtucker  2.8K Mar 15  2021 transInterp.sdss_to_des.r_gr_des.csv
# -rw-rw-r-- 1 dtucker  389K Mar 15  2021 qaPlot_transInterp.sdss_to_des.r_gr_des.png
# -rw-rw-r-- 1 dtucker  2.8K Mar 15  2021 transInterp.sdss_to_des.i_gr_des.csv
# -rw-rw-r-- 1 dtucker  382K Mar 15  2021 qaPlot_transInterp.sdss_to_des.i_gr_des.png
# -rw-rw-r-- 1 dtucker  2.7K Mar 15  2021 transInterp.sdss_to_des.z_gr_des.csv
# -rw-rw-r-- 1 dtucker  336K Mar 15  2021 qaPlot_transInterp.sdss_to_des.z_gr_des.png
# -rw-rw-r-- 1 dtucker  5.0K Mar 15  2021 transInterp.sdss_to_des.g_gi_des.csv
# -rw-rw-r-- 1 dtucker  352K Mar 15  2021 qaPlot_transInterp.sdss_to_des.g_gi_des.png
# -rw-rw-r-- 1 dtucker  5.2K Mar 15  2021 transInterp.sdss_to_des.r_gi_des.csv
# -rw-rw-r-- 1 dtucker  365K Mar 15  2021 qaPlot_transInterp.sdss_to_des.r_gi_des.png
# -rw-rw-r-- 1 dtucker  5.3K Mar 15  2021 transInterp.sdss_to_des.i_gi_des.csv
# -rw-rw-r-- 1 dtucker  351K Mar 15  2021 qaPlot_transInterp.sdss_to_des.i_gi_des.png
# -rw-rw-r-- 1 dtucker  5.2K Mar 15  2021 transInterp.sdss_to_des.z_gi_des.csv
# -rw-rw-r-- 1 dtucker  326K Mar 15  2021 qaPlot_transInterp.sdss_to_des.z_gi_des.png
# -rw-rw-r-- 1 dtucker  375K Mar 15  2021 qaPlot.sdss_to_des.dmag_g.gi_des.norder1.qa1.png
# -rw-rw-r-- 1 dtucker  363K Mar 15  2021 qaPlot.sdss_to_des.dmag_r.gi_des.norder1.qa1.png
# -rw-rw-r-- 1 dtucker  345K Mar 15  2021 qaPlot.sdss_to_des.dmag_i.gi_des.norder1.qa1.png
# -rw-rw-r-- 1 dtucker  383K Mar 15  2021 qaPlot.sdss_to_des.dmag_z.gi_des.norder1.qa1.png
# -rw-rw-r-- 1 dtucker   645 Mar 15  2021 transFit.sdss_to_des.dmag.gi_des.norder1.csv
# -rw-rw-r-- 1 dtucker  5.0K Mar 15  2021 transInterp.des_to_sdss.g_gi_des.csv
# -rw-rw-r-- 1 dtucker  352K Mar 15  2021 qaPlot_transInterp.des_to_sdss.g_gi_des.png
# -rw-rw-r-- 1 dtucker  5.2K Mar 15  2021 transInterp.des_to_sdss.r_gi_des.csv
# -rw-rw-r-- 1 dtucker  365K Mar 15  2021 qaPlot_transInterp.des_to_sdss.r_gi_des.png
# -rw-rw-r-- 1 dtucker  5.3K Mar 15  2021 transInterp.des_to_sdss.i_gi_des.csv
# -rw-rw-r-- 1 dtucker  351K Mar 15  2021 qaPlot_transInterp.des_to_sdss.i_gi_des.png
# -rw-rw-r-- 1 dtucker  5.2K Mar 15  2021 transInterp.des_to_sdss.z_gi_des.csv
# -rw-rw-r-- 1 dtucker  326K Mar 15  2021 qaPlot_transInterp.des_to_sdss.z_gi_des.png
# -rw-rw-r-- 1 dtucker  2.1G Mar 16  2021 atlas-refcat2_stripe82area.fits
# -rw-rw-r-- 1 dtucker  2.0G Mar 16  2021 match_y6a2_stripe82area_stars_ATLAS-REFCAT2.fits
# -rw-rw-r-- 1 dtucker  5.6K Mar 16  2021 transInterp.des_to_ref2.g_gi_des.csv
# -rw-rw-r-- 1 dtucker  392K Mar 16  2021 qaPlot_transInterp.des_to_ref2.g_gi_des.png
# -rw-rw-r-- 1 dtucker  5.9K Mar 16  2021 transInterp.des_to_ref2.r_gi_des.csv
# -rw-rw-r-- 1 dtucker  378K Mar 16  2021 qaPlot_transInterp.des_to_ref2.r_gi_des.png
# -rw-rw-r-- 1 dtucker  6.0K Mar 16  2021 transInterp.des_to_ref2.i_gi_des.csv
# -rw-rw-r-- 1 dtucker  370K Mar 16  2021 qaPlot_transInterp.des_to_ref2.i_gi_des.png
# -rw-rw-r-- 1 dtucker  5.9K Mar 16  2021 transInterp.des_to_ref2.z_gi_des.csv
# -rw-rw-r-- 1 dtucker  374K Mar 16  2021 qaPlot_transInterp.des_to_ref2.z_gi_des.png
# -rw-rw-r-- 1 dtucker  5.0K Mar 16  2021 transInterp.ref2_to_des.g_gi_ref2.csv
# -rw-rw-r-- 1 dtucker  396K Mar 16  2021 qaPlot_transInterp.ref2_to_des.g_gi_ref2.png
# -rw-rw-r-- 1 dtucker  5.3K Mar 16  2021 transInterp.ref2_to_des.r_gi_ref2.csv
# -rw-rw-r-- 1 dtucker  378K Mar 16  2021 qaPlot_transInterp.ref2_to_des.r_gi_ref2.png
# -rw-rw-r-- 1 dtucker  5.5K Mar 16  2021 transInterp.ref2_to_des.i_gi_ref2.csv
# -rw-rw-r-- 1 dtucker  380K Mar 16  2021 qaPlot_transInterp.ref2_to_des.i_gi_ref2.png
# -rw-rw-r-- 1 dtucker  5.4K Mar 16  2021 transInterp.ref2_to_des.z_gi_ref2.csv
# -rw-rw-r-- 1 dtucker  410K Mar 16  2021 qaPlot_transInterp.ref2_to_des.z_gi_ref2.png
# -rw-rw-r-- 1 dtucker  2.1M Mar 17  2021 TransformationInterpolations_DES_DR2_PS1_DR2.ipynb.XXX
# -rw-rw-r-- 1 dtucker  5.7K Mar 17  2021 transInterp.des_to_ps1.g_gi_des.csv
# -rw-rw-r-- 1 dtucker  388K Mar 17  2021 qaPlot_transInterp.des_to_ps1.g_gi_des.png
# -rw-rw-r-- 1 dtucker  5.9K Mar 17  2021 transInterp.des_to_ps1.r_gi_des.csv
# -rw-rw-r-- 1 dtucker  371K Mar 17  2021 qaPlot_transInterp.des_to_ps1.r_gi_des.png
# -rw-rw-r-- 1 dtucker  5.9K Mar 17  2021 transInterp.des_to_ps1.i_gi_des.csv
# -rw-rw-r-- 1 dtucker  374K Mar 17  2021 qaPlot_transInterp.des_to_ps1.i_gi_des.png
# -rw-rw-r-- 1 dtucker  5.9K Mar 17  2021 transInterp.des_to_ps1.z_gi_des.csv
# -rw-rw-r-- 1 dtucker  374K Mar 17  2021 qaPlot_transInterp.des_to_ps1.z_gi_des.png
# -rw-rw-r-- 1 dtucker  6.0K Mar 17  2021 transInterp.des_to_ps1.Y_gi_des.csv
# -rw-rw-r-- 1 dtucker  381K Mar 17  2021 qaPlot_transInterp.des_to_ps1.Y_gi_des.png
# -rw-rw-r-- 1 dtucker  5.0K Mar 17  2021 transInterp.ps1_to_des.g_gi_ps1.csv
# -rw-rw-r-- 1 dtucker  381K Mar 17  2021 qaPlot_transInterp.ps1_to_des.g_gi_ps1.png
# -rw-rw-r-- 1 dtucker  5.3K Mar 17  2021 transInterp.ps1_to_des.r_gi_ps1.csv
# -rw-rw-r-- 1 dtucker  373K Mar 17  2021 qaPlot_transInterp.ps1_to_des.r_gi_ps1.png
# -rw-rw-r-- 1 dtucker  5.3K Mar 17  2021 transInterp.ps1_to_des.i_gi_ps1.csv
# -rw-rw-r-- 1 dtucker  367K Mar 17  2021 qaPlot_transInterp.ps1_to_des.i_gi_ps1.png
# -rw-rw-r-- 1 dtucker  5.3K Mar 17  2021 transInterp.ps1_to_des.z_gi_ps1.csv
# -rw-rw-r-- 1 dtucker  372K Mar 17  2021 qaPlot_transInterp.ps1_to_des.z_gi_ps1.png
# -rw-rw-r-- 1 dtucker  5.3K Mar 17  2021 transInterp.ps1_to_des.Y_gi_ps1.csv
# -rw-rw-r-- 1 dtucker  346K Mar 17  2021 qaPlot_transInterp.ps1_to_des.Y_gi_ps1.png
# -rw-rw-r-- 1 dtucker  3.1K Mar 17  2021 transInterp.des_to_ps1.g_ri_des.csv
# -rw-rw-r-- 1 dtucker  374K Mar 17  2021 qaPlot_transInterp.des_to_ps1.g_ri_des.png
# -rw-rw-r-- 1 dtucker  3.0K Mar 17  2021 transInterp.des_to_ps1.r_ri_des.csv
# -rw-rw-r-- 1 dtucker  345K Mar 17  2021 qaPlot_transInterp.des_to_ps1.r_ri_des.png
# -rw-rw-r-- 1 dtucker  3.0K Mar 17  2021 transInterp.des_to_ps1.i_ri_des.csv
# -rw-rw-r-- 1 dtucker  312K Mar 17  2021 qaPlot_transInterp.des_to_ps1.i_ri_des.png
# -rw-rw-r-- 1 dtucker  3.0K Mar 17  2021 transInterp.des_to_ps1.z_ri_des.csv
# -rw-rw-r-- 1 dtucker  325K Mar 17  2021 qaPlot_transInterp.des_to_ps1.z_ri_des.png
# -rw-rw-r-- 1 dtucker  3.1K Mar 17  2021 transInterp.des_to_ps1.Y_ri_des.csv
# -rw-rw-r-- 1 dtucker  331K Mar 17  2021 qaPlot_transInterp.des_to_ps1.Y_ri_des.png
# -rw-rw-r-- 1 dtucker  3.1K Mar 17  2021 transInterp.ps1_to_des.g_ri_ps1.csv
# -rw-rw-r-- 1 dtucker  371K Mar 17  2021 qaPlot_transInterp.ps1_to_des.g_ri_ps1.png
# -rw-rw-r-- 1 dtucker  3.1K Mar 17  2021 transInterp.ps1_to_des.r_ri_ps1.csv
# -rw-rw-r-- 1 dtucker  301K Mar 17  2021 qaPlot_transInterp.ps1_to_des.r_ri_ps1.png
# -rw-rw-r-- 1 dtucker  3.1K Mar 17  2021 transInterp.ps1_to_des.i_ri_ps1.csv
# -rw-rw-r-- 1 dtucker  291K Mar 17  2021 qaPlot_transInterp.ps1_to_des.i_ri_ps1.png
# -rw-rw-r-- 1 dtucker  3.2K Mar 17  2021 transInterp.ps1_to_des.z_ri_ps1.csv
# -rw-rw-r-- 1 dtucker  305K Mar 17  2021 qaPlot_transInterp.ps1_to_des.z_ri_ps1.png
# -rw-rw-r-- 1 dtucker  3.1K Mar 17  2021 transInterp.ps1_to_des.Y_ri_ps1.csv
# -rw-rw-r-- 1 dtucker  326K Mar 17  2021 qaPlot_transInterp.ps1_to_des.Y_ri_ps1.png
# -rw-rw-r-- 1 dtucker  2.2M Mar 17  2021 TransformationInterpolations_DES_DR2_PS1_DR2.ipynb
# -rw-rw-r-- 1 dtucker  5.0K Mar 19  2021 transInterp.sdss_to_des.g_gi_sdss.csv
# -rw-rw-r-- 1 dtucker  352K Mar 19  2021 qaPlot_transInterp.sdss_to_des.g_gi_sdss.png
# -rw-rw-r-- 1 dtucker  5.0K Mar 19  2021 transInterp.sdss_to_des.r_gi_sdss.csv
# -rw-rw-r-- 1 dtucker  368K Mar 19  2021 qaPlot_transInterp.sdss_to_des.r_gi_sdss.png
# -rw-rw-r-- 1 dtucker  5.2K Mar 19  2021 transInterp.sdss_to_des.i_gi_sdss.csv
# -rw-rw-r-- 1 dtucker  363K Mar 19  2021 qaPlot_transInterp.sdss_to_des.i_gi_sdss.png
# -rw-rw-r-- 1 dtucker  5.0K Mar 19  2021 transInterp.sdss_to_des.z_gi_sdss.csv
# -rw-rw-r-- 1 dtucker  330K Mar 19  2021 qaPlot_transInterp.sdss_to_des.z_gi_sdss.png
# -rw-rw-r-- 1 dtucker  371K Mar 23  2021 qaPlot.sdss_to_des.fit.dmag_g.gi_sdss.norder1.qa1.png
# -rw-rw-r-- 1 dtucker  348K Mar 23  2021 qaPlot.sdss_to_des.fit.dmag_r.gi_sdss.norder1.qa1.png
# -rw-rw-r-- 1 dtucker  349K Mar 23  2021 qaPlot.sdss_to_des.fit.dmag_i.gi_sdss.norder1.qa1.png
# -rw-rw-r-- 1 dtucker  386K Mar 23  2021 qaPlot.sdss_to_des.fit.dmag_z.gi_sdss.norder1.qa1.png
# -rw-rw-r-- 1 dtucker
norder2.qa1.png
# -rw-rw-r-- 1 dtucker   437 Jun 25  2021 transFit.des_to_sdss_iz.dmag.iz_des.norder2.csv
# -rw-rw-r-- 1 dtucker  338K Jun 25  2021 qaPlot.sdss_to_des_iz.fit.dmag_i.iz_sdss.norder2.qa1.png
# -rw-rw-r-- 1 dtucker  376K Jun 25  2021 qaPlot.sdss_to_des_iz.fit.dmag_z.iz_sdss.norder2.qa1.png
# -rw-rw-r-- 1 dtucker   443 Jun 25  2021 transFit.sdss_to_des_iz.dmag.iz_sdss.norder2.csv
# -rw-rw-r-- 1 dtucker  2.4K Jun 25  2021 transInterp.sdss_to_des_iz.i_iz_sdss.csv
# -rw-rw-r-- 1 dtucker  354K Jun 25  2021 qaPlot_transInterp.sdss_to_des_iz.i_iz_sdss.png
# -rw-rw-r-- 1 dtucker  667K Jun 25  2021 TransformationInterpolations_DES_DR2_SDSS_DR13.ipynb
# -rw-rw-r-- 1 dtucker   13K Jul 30  2021 Untitled.ipynb
# -rw-rw-r-- 1 dtucker  2.8G Aug  3  2021 match_y6a2_stripe82area_stars_GAIAedr3.fits
# -rw-rw-r-- 1 dtucker   14K Aug  4  2021 transInterp.gaia_to_des.g_des_BP_RP_gaia.csv
# -rw-rw-r-- 1 dtucker  350K Aug  4  2021 qaPlot_transInterp.gaia_to_des.g_des_BP_RP_gaia.png
# -rw-rw-r-- 1 dtucker   14K Aug  4  2021 transInterp.gaia_to_des.r_des_BP_RP_gaia.csv
# -rw-rw-r-- 1 dtucker  370K Aug  4  2021 qaPlot_transInterp.gaia_to_des.r_des_BP_RP_gaia.png
# -rw-rw-r-- 1 dtucker   14K Aug  4  2021 transInterp.gaia_to_des.i_des_BP_RP_gaia.csv
# -rw-rw-r-- 1 dtucker  356K Aug  4  2021 qaPlot_transInterp.gaia_to_des.i_des_BP_RP_gaia.png
# -rw-rw-r-- 1 dtucker   14K Aug  4  2021 transInterp.gaia_to_des.z_des_BP_RP_gaia.csv
# -rw-rw-r-- 1 dtucker  353K Aug  4  2021 qaPlot_transInterp.gaia_to_des.z_des_BP_RP_gaia.png
# -rw-rw-r-- 1 dtucker   14K Aug  4  2021 transInterp.gaia_to_des.Y_des_BP_RP_gaia.csv
# -rw-rw-r-- 1 dtucker  357K Aug  4  2021 qaPlot_transInterp.gaia_to_des.Y_des_BP_RP_gaia.png
# -rw-rw-r-- 1 dtucker   16K Aug  4  2021 transInterp.des_to_gaia.G_gaia_gi_des.csv
# -rw-rw-r-- 1 dtucker  339K Aug  4  2021 qaPlot_transInterp.des_to_gaia.G_gaia_gi_des.png
# -rw-rw-r-- 1 dtucker  313K Aug  4  2021 qaPlot.gaia_to_des.fit.dmag_g_des-G_gaia.BP_RP_gaia.norder2.qa1.png
# -rw-rw-r-- 1 dtucker   369 Aug  4  2021 transFit.gaia_to_des.dmag_g_des-G_gaia.BP_RP_gaia.norder2.csv
# -rw-rw-r-- 1 dtucker  301K Aug  4  2021 qaPlot.gaia_to_des.fit.dmag_r_des-G_gaia.BP_RP_gaia.norder2.qa1.png
# -rw-rw-r-- 1 dtucker   365 Aug  4  2021 transFit.gaia_to_des.dmag_r_des-G_gaia.BP_RP_gaia.norder2.csv
# -rw-rw-r-- 1 dtucker  308K Aug  4  2021 qaPlot.gaia_to_des.fit.dmag_i_des-G_gaia.BP_RP_gaia.norder2.qa1.png
# -rw-rw-r-- 1 dtucker   366 Aug  4  2021 transFit.gaia_to_des.dmag_i_des-G_gaia.BP_RP_gaia.norder2.csv
# -rw-rw-r-- 1 dtucker  302K Aug  4  2021 qaPlot.gaia_to_des.fit.dmag_z_des-G_gaia.BP_RP_gaia.norder2.qa1.png
# -rw-rw-r-- 1 dtucker   368 Aug  4  2021 transFit.gaia_to_des.dmag_z_des-G_gaia.BP_RP_gaia.norder2.csv
# -rw-rw-r-- 1 dtucker  297K Aug  4  2021 qaPlot.gaia_to_des.fit.dmag_Y_des-G_gaia.BP_RP_gaia.norder2.qa1.png
# -rw-rw-r-- 1 dtucker   366 Aug  4  2021 transFit.gaia_to_des.dmag_Y_des-G_gaia.BP_RP_gaia.norder2.csv
# -rw-rw-r-- 1 dtucker  298K Aug  4  2021 qaPlot.gaia_to_des.fit.dmag_g_des-G_gaia.BP_RP_gaia.norder3.qa1.png
# -rw-rw-r-- 1 dtucker   386 Aug  4  2021 transFit.gaia_to_des.dmag_g_des-G_gaia.BP_RP_gaia.norder3.csv
# -rw-rw-r-- 1 dtucker  323K Aug  4  2021 qaPlot.gaia_to_des.fit.dmag_r_des-G_gaia.BP_RP_gaia.norder3.qa1.png
# -rw-rw-r-- 1 dtucker   389 Aug  4  2021 transFit.gaia_to_des.dmag_r_des-G_gaia.BP_RP_gaia.norder3.csv
# -rw-rw-r-- 1 dtucker  295K Aug  4  2021 qaPlot.gaia_to_des.fit.dmag_i_des-G_gaia.BP_RP_gaia.norder3.qa1.png
# -rw-rw-r-- 1 dtucker   392 Aug  4  2021 transFit.gaia_to_des.dmag_i_des-G_gaia.BP_RP_gaia.norder3.csv
# -rw-rw-r-- 1 dtucker  313K Aug  4  2021 qaPlot.gaia_to_des.fit.dmag_z_des-G_gaia.BP_RP_gaia.norder3.qa1.png
# -rw-rw-r-- 1 dtucker   388 Aug  4  2021 transFit.gaia_to_des.dmag_z_des-G_gaia.BP_RP_gaia.norder3.csv
# -rw-rw-r-- 1 dtucker  312K Aug  4  2021 qaPlot.gaia_to_des.fit.dmag_Y_des-G_gaia.BP_RP_gaia.norder3.qa1.png
# -rw-rw-r-- 1 dtucker   388 Aug  4  2021 transFit.gaia_to_des.dmag_Y_des-G_gaia.BP_RP_gaia.norder3.csv
# -rw-rw-r-- 1 dtucker  300K Aug  4  2021 qaPlot.des_to_gaia.fit.dmag_G_gaia-i_des.gi_des.norder3.qa1.png
# -rw-rw-r-- 1 dtucker   390 Aug  4  2021 transFit.des_to_gaia.dmag_G_gaia-i_des.gi_des.norder3.csv
# -rw-rw-r-- 1 dtucker   11K Feb  4  2022 transInterp.gaia_to_sdss.g_sdss_BP_RP_gaia.csv
# -rw-rw-r-- 1 dtucker  345K Feb  4  2022 qaPlot_transInterp.gaia_to_sdss.g_sdss_BP_RP_gaia.png
# -rw-rw-r-- 1 dtucker   11K Feb  4  2022 transInterp.gaia_to_sdss.r_sdss_BP_RP_gaia.csv
# -rw-rw-r-- 1 dtucker  369K Feb  4  2022 qaPlot_transInterp.gaia_to_sdss.r_sdss_BP_RP_gaia.png
# -rw-rw-r-- 1 dtucker   11K Feb  4  2022 transInterp.gaia_to_sdss.i_sdss_BP_RP_gaia.csv
# -rw-rw-r-- 1 dtucker  356K Feb  4  2022 qaPlot_transInterp.gaia_to_sdss.i_sdss_BP_RP_gaia.png
# -rw-rw-r-- 1 dtucker   11K Feb  4  2022 transInterp.gaia_to_sdss.z_sdss_BP_RP_gaia.csv
# -rw-rw-r-- 1 dtucker  347K Feb  4  2022 qaPlot_transInterp.gaia_to_sdss.z_sdss_BP_RP_gaia.png
# -rw-rw-r-- 1 dtucker   11K Feb  4  2022 transInterp.gaia_to_sdss.gr_sdss_BP_RP_gaia.csv
# -rw-rw-r-- 1 dtucker  381K Feb  4  2022 qaPlot_transInterp.gaia_to_sdss.gr_sdss_BP_RP_gaia.png
# -rw-rw-r-- 1 dtucker  1.2M Feb 15  2022 TransformationEquations_DES_DR2_SDSS_DR13.ipynb
# -rw-rw-r-- 1 dtucker  710K Feb 15  2022 TransformationInterpolations_DES_DR2_GAIA_EDR3.ipynb
# -rw-rw-r-- 1 dtucker  2.4M Feb 15  2022 TransformationInterpolations_SDSS_GAIA_EDR3.ipynb
# -rw-rw-r-- 1 dtucker  2.3M Apr  1 17:21 TransformationEquations_DES_DR2_PS1_DR2.ipynb
# -rw-rw-r-- 1 dtucker  2.2M Apr 19 15:37 TransformationInterpolations_DES_DR2_ATLAS-REFCAT2.ipynb
# -rw-rw-r-- 1 dtucker  629K Apr 19 15:37 TransformationEquations_DES_DR2_GAIA_EDR3.ipynb
# -rw-rw-r-- 1 dtucker   56K Jul 11 18:16 ATLAS_REFCAT2_near_Stripe82.ipynb
# drwxrwxr-x 4 dtucker  8.0K Jul 20 19:39 Stetson_UBVRI/
# -rw-rw-r-- 1 dtucker  1.9G Jul 22 17:55 match_y6a2_stripe82area_stars_GAIAedr3_SDSSDR13.fits
# -rw-rw-r-- 1 dtucker  2.8K Sep 23 16:58 transInterp.sdss_to_gaia.G_gaia_gr_sdss.csv
# -rw-rw-r-- 1 dtucker  293K Sep 23 16:58 qaPlot_transInterp.sdss_to_gaia.G_gaia_gr_sdss.png
# -rw-rw-r-- 1 dtucker  1.5K Sep 23 17:05 transInterp.sdss_to_gaia.G_gaia_iz_sdss.csv
# -rw-rw-r-- 1 dtucker  279K Sep 23 17:05 qaPlot_transInterp.sdss_to_gaia.G_gaia_iz_sdss.png
# -rw-rw-r-- 1 dtucker  245K Sep 23 17:12 TransformationInterpolations_SDSSDR13_GAIA_EDR3.ipynb
# -rw-rw-r-- 1 dtucker  4.1K Sep 23 17:14 transInterp.sdss_to_gaia.G_gaia_gi_sdss.csv
# -rw-rw-r-- 1 dtucker  272K Sep 23 17:14 qaPlot_transInterp.sdss_to_gaia.G_gaia_gi_sdss.png

# %%
#%pwd
